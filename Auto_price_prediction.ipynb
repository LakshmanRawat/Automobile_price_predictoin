# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option("display.max_columns",None)

# %% [markdown]
# # 2. Loading Dataset

# %%
df  = pd.read_csv("auto_imports.csv")

# %%
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 195 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 196 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 197 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 198 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 199 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ## a) Renaming the columns

# %%
df.columns = ['Symboling','normalized_losses','make','fuel_type','aspiration','num_of_doors','body_style','drive_wheels','engine_location','wheel_base','length','width','height','curb_weight','engine_type','num_of_cylinder','engine_size','fuel_system','bore','stroke','compression_ratio','horsepower','peak_rpm','city_mpg','highway_mpg','price']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symboling          200 non-null    int64
#  1   normalized_losses  200 non-null    object
#  2   make               200 non-null    object
#  3   fuel_type          200 non-null    object
#  4   aspiration         200 non-null    object
#  5   num_of_doors       200 non-null    object
#  6   body_style         200 non-null    object
#  7   drive_wheels       200 non-null    object
#  8   engine_location    200 non-null    object
#  9   wheel_base         200 non-null    float64
#  10  length             200 non-null    float64
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb_weight        200 non-null    int64
#  14  engine_type        200 non-null    object
#  15  num_of_cylinder    200 non-null    object
# ...

# %%
df
# Out:
#      Symboling normalized_losses         make fuel_type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            1                 ?  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2                 ?         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 195         -1                95        volvo       gas        std
# 196         -1                95        volvo       gas      turbo
# 197         -1                95        volvo       gas        std
# 198         -1                95        volvo    diesel      turbo
# 199         -1                95        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# ## b)  Checking Missing/Null Values

# %%
df.isnull().sum()
# Out:
# Symboling            0
# normalized_losses    0
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinder      0
# engine_size          0
# fuel_system          0
# bore                 0
# stroke               0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %% [markdown]
# #### There is no null value, But there is some values are placed as '?'

# %% [markdown]
# #### counting '?' entries  in each row

# %%
df.replace('?',np.nan,inplace=True)

# %% [markdown]
# ### Converting Data Type

# %%
df['num_of_doors']=df['num_of_doors'].map({'two':2,'four':4})

# %%
df[['peak_rpm', 'horsepower','stroke','bore','normalized_losses','num_of_doors']] = df[['peak_rpm', 'horsepower','stroke','bore','normalized_losses','num_of_doors']].apply(pd.to_numeric)

# %% [markdown]
# ### Handling Null Values

# %%
df['normalized_losses'].fillna(int(df['normalized_losses'].mean()),inplace=True)

# %%
a = df[df['num_of_doors'].isna()]
a
# Out:
#     Symboling  normalized_losses   make fuel_type aspiration  num_of_doors  \
# 25          1              148.0  dodge       gas      turbo           NaN
# 59          0              122.0  mazda    diesel        std           NaN
#
#    body_style drive_wheels engine_location  wheel_base  length  width  height  \
# 25      sedan          fwd           front        93.7   157.3   63.8    50.6
# 59      sedan          fwd           front        98.8   177.8   66.5    55.5
#
#     curb_weight engine_type num_of_cylinder  engine_size fuel_system  bore  \
# 25         2191         ohc            four           98        mpfi  3.03
# 59         2443         ohc            four          122         idi  3.39
#
#     stroke  compression_ratio  horsepower  peak_rpm  city_mpg  highway_mpg  \
# 25    3.39                7.6       102.0    5500.0        24           30
# 59    3.39               22.7        64.0    4650.0        36           42
#
#     price
# 25   8558
# 59  10795

# %%
a = df[df['body_style']=='sedan']
a['num_of_doors'].value_counts()
# Out:
# 4.0    78
# 2.0    14
# Name: num_of_doors, dtype: int64

# %%
df.bore.fillna(df['bore'].mean(),inplace=True)

# %%
df['num_of_doors'].fillna(4,inplace=True)

# %%
df.stroke.fillna(df['stroke'].mean(),inplace=True)

# %%
df.horsepower.fillna(df['horsepower'].mean(),inplace=True)

# %%
df.peak_rpm.fillna(df['peak_rpm'].mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Symboling          200 non-null    int64
#  1   normalized_losses  200 non-null    float64
#  2   make               200 non-null    object
#  3   fuel_type          200 non-null    object
#  4   aspiration         200 non-null    object
#  5   num_of_doors       200 non-null    float64
#  6   body_style         200 non-null    object
#  7   drive_wheels       200 non-null    object
#  8   engine_location    200 non-null    object
#  9   wheel_base         200 non-null    float64
#  10  length             200 non-null    float64
#  11  width              200 non-null    float64
#  12  height             200 non-null    float64
#  13  curb_weight        200 non-null    int64
#  14  engine_type        200 non-null    object
#  15  num_of_cylinder    200 non-null    object
# ...

# %% [markdown]
# ## EDA

# %%
sns.countplot(x='fuel_type',data=df)
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='summer')
# Out:
# <AxesSubplot:>

# %%
# features with high corrrelation with price are horse_power,engine_size,curb_weight,

# %%
ax = sns.pairplot(df[["width", "curb_weight","engine_size","horsepower","highway_mpg","fuel_type","price",]], hue="fuel_type",palette='dark') #diag_kind="hist"

# %%
#now preprocess the categorical features 
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in list(df.columns):
    if df[i].dtype=='object':
        df[i]=le.fit_transform(df[i])

# %% [markdown]
# ## Building Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split # for spliting the data into training and test set
from sklearn import metrics # for validating the accuracy of the model

# %%
"""for i in range(len(correlation_matrix .columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname) """

# %%
y=df['price']
X=df.drop(['price'],axis=1)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler 
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %% [markdown]
# ### Train Test Split

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
'''Get Predictions & Print Metrics'''
predicts = lr.predict(X_test)
print("""
        Mean Squared Error: {}
        R2 Score: {}
        Mean Absolute Error: {}
     """.format(
        mean_squared_error(y_test, predicts),
        r2_score(y_test,predicts),
        mean_absolute_error(y_test,predicts)
        ))

# %% [markdown]
# ### Root mean Squared error

# %%
from sklearn.metrics import mean_squared_error
import math
rmse = math.sqrt(mean_squared_error(y_test,predicts))
print('RMSE of the model:',rmse)

# %% [markdown]
# ### R squared Error

# %%
r2_train = lr.score(X_train,y_train)
r2_test = lr.score(X_test,y_test)
print('R Squared Error for Train set:',r2_train)
print('R Squared Error for Test set:',r2_test)
